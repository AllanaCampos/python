# %%
import DataFruta as df

# %%
idades = df.GeraDados.geraListaIdade(5000)
#print(idades)

# %%
# %timeit idades.mostraMaior()
# Out:
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# Maior idade: 66
# ...

# %%
# %timeit idades.mostraMediana()
# Out:
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# Mediana das idades: 42.0
# ...

# %%
# %timeit idades.mostraMenor()
# Out:
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# Menor idade: 18
# ...
